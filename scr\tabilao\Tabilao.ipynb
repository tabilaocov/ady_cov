# %% [markdown]
# <a href="https://colab.research.google.com/github/herysedra/ady_cov/blob/master/scr%5Ctabilao%5CTabilao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
import matplotlib
import pickle

import pymc3 as pm
import theano.tensor as tt
import theano
import datetime
import time


import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns
import pandas.testing as tm


tilyvoa = pd.read_csv("/content/drive/My Drive/data/tilyvoa.csv")


tilyvoafar = tilyvoa.groupby('Faritra')
tilyvoamdg = tilyvoafar.get_group('Madagasikara')
tilyvoamdg.set_index('Daty', inplace=True)

tilyvoamdg.index = pd.to_datetime(tilyvoamdg.index)


tilyvoatana = tilyvoafar.get_group('Antananarivo')
tilyvoatana.set_index('Daty', inplace=True)

tilyvoatana.index = pd.to_datetime(tilyvoatana.index)

tilyvoatoa = tilyvoafar.get_group('Toamasina')
tilyvoatoa.set_index('Daty', inplace=True)

tilyvoatoa.index = pd.to_datetime(tilyvoatoa.index)


path_to_save = '/content/drive/My Drive/sary/'
path_data = '/content/drive/My Drive/data/'
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
daty_data_manom = datetime.date(2020,5,24)
daty_data_mifar = datetime.date(2020,7,24)

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.bar(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar,'Voatomb'], width = 0.2, color='black',label="Antontan'isa MDG CCO")


ax.set(xlabel ='Andro', ylabel = "Isan'ny voa vaovao")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'best')

plt.ylim(0,540)
plt.savefig(path_to_save+'voavaozao.eps')
plt.savefig(path_to_save+'voavaozao.png')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.bar(tilyvoatana.loc[daty_data_manom:daty_data_mifar].index, tilyvoatana.loc[daty_data_manom:daty_data_mifar,'Voatomb'], width=0.2, color='black',label="Antontan'isa Antananarivo CCO")


ax.set(xlabel ='Andro', ylabel = "Isan'ny voa vaovao")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'best')

plt.ylim(0,550)
plt.savefig(path_to_save+'voavaotanazao.eps')
plt.savefig(path_to_save+'voavaotanazao.png')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.bar(tilyvoatoa.loc[daty_data_manom:daty_data_mifar].index, tilyvoatoa.loc[daty_data_manom:daty_data_mifar,'Voatomb'], width=0.2, color='black',label="Antontan'isa Toamasina CCO")


ax.set(xlabel ='Andro', ylabel = "Isan'ny voa vaovao")

date_form = DateFormatter("%d/%m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'best')

plt.ylim(0,50)
plt.savefig(path_to_save+'voavaotoazao.eps')
plt.savefig(path_to_save+'voavaotoazao.png')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.plot(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar,'Voareh tvm'], color='black',label="Antontan'isa MDG CCO")

ax.set(xlabel ='Andro', ylabel = "Isan'ny voa rehetra")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.legend(loc= 'upper left')

plt.ylim(0,9500)
plt.savefig(path_to_save+'voarehzao.eps')
plt.savefig(path_to_save+'voarehzao.png')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
tilyvoamdg.loc['Voareh tvm'].loc[datetime.date(2020,6,30)]

# %% [markdown]
# ## Sitrana

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.plot(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar, 'Sitranreh tvm'], color='green',label="Antontan'isa MDG CCO")

ax.set(xlabel ='Andro', ylabel = "Isan'ny sitrana rehetra")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=5))
ax.legend(loc= 'best')

plt.ylim(0,6500)
plt.savefig(path_to_save+'sitrrehzao.eps')
plt.savefig(path_to_save+'sitrrehzao.png')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.bar(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar,'Sitranvao tvm'], width=0.2, color='green',label="Antontan'isa MDG CCO")

ax.set(xlabel ='Andro', ylabel = "Isan'ny sitrana vaovao")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'best')

plt.ylim(0,650)
plt.savefig(path_to_save+'sitrvaozao.eps')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.plot(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar ,'Tahasitr'], color='green',label="Antontan'isa MDG CCO")
ax.axhline(y=0.5, color='b', linestyle='dashed', label ="Tahan'ny sitrana = 50%")

ax.set(xlabel ='Andro', ylabel = "Tahan'ny sitrana hatrizay oharina @ voa hatrizay")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'best')

plt.ylim(0,1)
plt.savefig(path_to_save+'tahasitrzao.eps')
plt.savefig(path_to_save+'tahasitrzao.png')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Mametraka ny marika 'tahabe' na 'tahakely' arakaraka ny tahan'ny sitrana

tilyvoamdg['Mombatahasitr'] = np.where(tilyvoamdg['Tahasitr']>=0.5, 'tahabe', 'tahakely')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
res = [tilyvoamdg['Tahasitr'][i + 1] - tilyvoamdg['Tahasitr'][i] for i in range(len(tilyvoamdg['Tahasitr'])-1)]

# %%
tilyvoamdg.loc[tilyvoamdg['Mombatahasitr'] == 'tahabe']
# Out:
#            Loharano       Faritra  ... Mombatahasitr Mombatahatsv
# Daty                               ...
# 2020-04-24      CCO  Madagasikara  ...        tahabe       tahabe
# 2020-04-25   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-04-26   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-04-27   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-04-28   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-04-29   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-04-30   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-01   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-02   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-03   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-04   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-05   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-06   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-07   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-08   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-09   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-10   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-11   FB-TVM  Madagasikara  ...        tahabe       tahabe
# 2020-05-12   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-05-13   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-09   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-10   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-15   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-20   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-21   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-22   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-23   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-24   FB-TVM  Madagasikara  ...        tahabe     tahakely
#
# [28 rows x 27 columns]

# %%
tilyvoamdg.loc[tilyvoamdg['Tahasitr'] == np.nanmax(tilyvoamdg['Tahasitr'])]

# %%
tilyvoamdg.loc[tilyvoamdg['Mombatahasitr'] == 'tahakely']
# Out:
#            Loharano       Faritra MRC Rt  ... Unnamed: 25  Mombatahasitr  Mombatahatsv
# Daty                                      ...
# 2020-03-18      CCO  Madagasikara    NaN  ...         NaN       tahakely        tahabe
# 2020-03-19      CCO  Madagasikara    NaN  ...         NaN       tahakely        tahabe
# 2020-03-20      CCO  Madagasikara    NaN  ...         NaN       tahakely        tahabe
# 2020-03-21      CCO  Madagasikara    NaN  ...         NaN       tahakely        tahabe
# 2020-03-22      CCO  Madagasikara    NaN  ...         NaN       tahakely        tahabe
# ...             ...           ...    ...  ...         ...            ...           ...
# 2020-07-14   FB-TVM  Madagasikara    NaN  ...         NaN       tahakely      tahakely
# 2020-07-16   FB-TVM  Madagasikara    NaN  ...         NaN       tahakely      tahakely
# 2020-07-17   FB-TVM  Madagasikara    NaN  ...         NaN       tahakely      tahakely
# 2020-07-18   FB-TVM  Madagasikara    NaN  ...         NaN       tahakely      tahakely
# 2020-07-19   FB-TVM  Madagasikara    NaN  ...         NaN       tahakely      tahakely
#
# [101 rows x 27 columns]

# %%
fig, ax = plt.subplots(figsize=(14, 14))

ax.bar(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar,'Tsyvoatomb'], width= 0.2, color = 'green',label = 'Voatily tsy voa (MDG)')
ax.bar(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar,'Voatomb'], width= 0.2, bottom = tilyvoamdg.loc[daty_data_manom:daty_data_mifar,'Tsyvoatomb'], color = 'red', label = 'Voatily voa (MDG)')

ax.set(xlabel ='Andro', ylabel = "Isan'ny voatily")

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'upper left')

plt.ylim(0,1400)
plt.savefig(path_to_save+'mdgtahatv.eps')
plt.savefig(path_to_save+'mdgtahatv.png')

plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Tahan'ireo voatily tsy voa

# %%
tilyvoamdg.loc[datetime.date(2020,6,30), 'Tahatsv']
# Out:
# 0.4865

# %%
fig, ax = plt.subplots(figsize=(12, 12))

ax.bar(tilyvoamdg.loc[daty_data_manom:daty_data_mifar].index, tilyvoamdg.loc[daty_data_manom:daty_data_mifar, 'Tahatsv'],  width= 0.2, color= 'blue', label = "Tahan'ny voatily tsy voa (MDG)")

              
ax.set(xlabel ='Andro', ylabel = "Taha")

plt.ylim(0.4,1)

date_form = DateFormatter("%d/%-m")
ax.xaxis.set_major_formatter(date_form)

ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.legend(loc= 'best')

plt.savefig(path_to_save+'mdgtahatsv.eps')
plt.savefig(path_to_save+'mdgtahatsv.png')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
tilyvoamdg['Mombatahatsv'] = np.where(tilyvoamdg['Tahatsv']>=0.8, 'tahabe', 'tahakely')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
tilyvoamdg.loc[tilyvoamdg['Mombatahatsv'] == 'tahabe']
# Out:
#            Loharano       Faritra  ... Unnamed: 25 Mombatahatsv
# Daty                               ...
# 2020-03-18      CCO  Madagasikara  ...         NaN       tahabe
# 2020-03-19      CCO  Madagasikara  ...         NaN       tahabe
# 2020-03-20      CCO  Madagasikara  ...         NaN       tahabe
# 2020-03-21      CCO  Madagasikara  ...         NaN       tahabe
# 2020-03-22      CCO  Madagasikara  ...         NaN       tahabe
# ...             ...           ...  ...         ...          ...
# 2020-06-22   FB-TVM  Madagasikara  ...   1.17-1.76       tahabe
# 2020-06-23   FB-TVM  Madagasikara  ...         NaN       tahabe
# 2020-06-24   FB-TVM  Madagasikara  ...         NaN       tahabe
# 2020-06-27   FB-TVM  Madagasikara  ...         NaN       tahabe
# 2020-06-28   FB-TVM  Madagasikara  ...         NaN       tahabe
#
# [89 rows x 26 columns]

# %%
tilyvoamdg.loc[daty_data_manom:daty_data_mifar].loc[tilyvoamdg['Mombatahatsv'] == 'tahabe']
# Out:
#            Loharano       Faritra  ... Mombatahasitr Mombatahatsv
# Daty                               ...
# 2020-05-24   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-25   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-26   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-27   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-28   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-29   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-30   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-05-31   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-01   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-02   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-05   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-06   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-07   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-08   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-09   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-10   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-11   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-12   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-13   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-14   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-15   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-16   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-18   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-19   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-21   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-22   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-23   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-24   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-27   FB-TVM  Madagasikara  ...      tahakely       tahabe
# 2020-06-28   FB-TVM  Madagasikara  ...      tahakely       tahabe
#
# [30 rows x 27 columns]

# %%
tilyvoamdg.loc[tilyvoamdg['Mombatahatsv'] == 'tahakely']
# Out:
#            Loharano       Faritra  ... Mombatahasitr Mombatahatsv
# Daty                               ...
# 2020-03-27      CCO  Madagasikara  ...      tahakely     tahakely
# 2020-04-02      CCO  Madagasikara  ...      tahakely     tahakely
# 2020-04-16      CCO  Madagasikara  ...      tahakely     tahakely
# 2020-04-19      CCO  Madagasikara  ...      tahakely     tahakely
# 2020-05-12   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-05-13   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-05-14   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-05-17   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-03   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-04   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-17   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-20   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-25   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-26   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-29   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-30   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-01   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-02   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-03   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-04   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-05   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-06   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-07   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-08   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-09   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-10   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-11   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-12   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-13   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-14   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-15   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-16   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-17   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-18   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-19   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-20   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-21   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-22   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-23   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-24   FB-TVM  Madagasikara  ...        tahabe     tahakely
#
# [40 rows x 27 columns]

# %%
tilyvoamdg.loc[daty_data_manom:daty_data_mifar].loc[tilyvoamdg['Mombatahatsv'] == 'tahakely']
# Out:
#            Loharano       Faritra  ... Mombatahasitr Mombatahatsv
# Daty                               ...
# 2020-06-03   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-04   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-17   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-20   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-25   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-26   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-29   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-06-30   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-01   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-02   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-03   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-04   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-05   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-06   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-07   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-08   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-09   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-10   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-11   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-12   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-13   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-14   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-15   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-16   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-17   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-18   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-19   FB-TVM  Madagasikara  ...      tahakely     tahakely
# 2020-07-20   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-21   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-22   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-23   FB-TVM  Madagasikara  ...        tahabe     tahakely
# 2020-07-24   FB-TVM  Madagasikara  ...        tahabe     tahakely
#
# [32 rows x 27 columns]
